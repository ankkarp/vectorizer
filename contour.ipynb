# %%
from neural import Vectorizer

# %%
v = Vectorizer()
# Out:
# 1.0
# [[4. 2. 4.]
#  [2. 0. 2.]
#  [4. 2. 4.]]

# %%
v.gy
# Out:
# array([[ -19., -138.,  -19.],
#        [  -0.,   -0.,   -0.],
#        [  19.,  138.,   19.]])

# %%
v.x
# Out:
# array([[-1,  0,  1],
#        [-1,  0,  1],
#        [-1,  0,  1]])

# %%
v.contour('test.png')
# Out:
# array([[ 6,  5,  5, ..., 62, 62, 71],
#        [ 5,  1,  1, ...,  7, 10, 62],
#        [ 5,  1,  0, ...,  0,  7, 62],
#        ...,
#        [ 2,  0,  0, ...,  1,  1,  7],
#        [ 2,  0,  0, ...,  1,  1,  7],
#        [ 3,  2,  2, ...,  7,  7,  8]])
